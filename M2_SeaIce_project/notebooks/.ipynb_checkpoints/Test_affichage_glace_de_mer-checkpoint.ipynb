# %% [markdown]
# # Test affichage glace de mer

# %%
from watermark import watermark
# %load_ext watermark
print(watermark())
# Out:
# Last updated: 2025-07-16T07:49:51.635460+00:00
#
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.17.2
#
# Compiler    : GCC 13.3.0
# OS          : Linux
# Release     : 6.8.0-63-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit

# %%
import sys
import os

# Chemin absolu vers le dossier codes_ORL_evaluation
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Ajout du chemin au sys.path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Projet root ajouté au path:", project_root)
# Out:
# Projet root ajouté au path: /home/jovyan/M2_SeaIce_project

# %%
pip install cdo
# Out:
# ...
#   Using cached cdo-1.6.1-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached cdo-1.6.1-py3-none-any.whl (16 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from module import *
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
# %watermark --iversions
# Out:
# netCDF4   : 1.7.2
# xarray    : 2025.1.1
# pandas    : 2.2.3
# seaborn   : 0.13.2
# watermark : 2.5.0
# skimage   : 0.25.0
# sys       : 3.12.8 | packaged by conda-forge | (main, Dec  5 2024, 14:24:40) [GCC 13.3.0]
# matplotlib: 3.10.0
# cdo       : 1.6.1
# xesmf     : 0.8.8
# csv       : 1.0
# cartopy   : 0.24.0
# numpy     : 2.0.2

# %%
path_seaice = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_MRI-ESM2-0_historical_r1i1p1f1_gn_185001-201412.nc"

# %%
sea_ice = xr.open_dataset(path_seaice)

# %%
sea_ice
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:             (time: 1980, bnds: 2, y: 363, x: 360, vertices: 4)
# Coordinates:
#   * time                (time) datetime64[ns] 16kB 1850-01-16T12:00:00 ... 20...
#   * y                   (y) float64 3kB -78.0 -77.5 -77.0 ... 149.7 151.8 154.0
#   * x                   (x) float64 3kB 0.0 1.0 2.0 3.0 ... 357.0 358.0 359.0
#     latitude            (y, x) float64 1MB ...
#     longitude           (y, x) float64 1MB ...
#     type                |S7 7B ...
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (time, bnds) datetime64[ns] 32kB ...
#     y_bnds              (y, bnds) float64 6kB ...
#     x_bnds              (x, bnds) float64 6kB ...
#     vertices_latitude   (y, x, vertices) float64 4MB ...
#     vertices_longitude  (y, x, vertices) float64 4MB ...
#     siconc              (time, y, x) float32 1GB ...
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
# ...

# %%
sea_ice["siconc"][1900].plot()

# %%
path_seaice2 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_FGOALS-f3-L_historical_r1i1p1f1_gn_185001-201412.nc"

# %%
sea_ice2 = xr.open_dataset(path_seaice2)

# %%
sea_ice2["siconc"][1900].plot()

# %%
path_seaice3 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_NESM3_historical_r1i1p1f1_gn_185001-201412.nc"

# %%
sea_ice3 = xr.open_dataset(path_seaice3)

# %%
sea_ice3["siconc"][1900].plot()

# %%
path_seaice4 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_FIO-ESM-2-0_historical_r1i1p1f1_gn_185001-201412.nc"

# %%
sea_ice4 = xr.open_dataset(path_seaice4)

# %%
sea_ice4["siconc"][1900].plot()

# %%
path_seaice5 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412.nc"

# %%
sea_ice5 = xr.open_dataset(path_seaice5)

# %%
sea_ice5["siconc"][1900].plot()

# %%
path_seaice6 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CAMS-CSM1-0_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice6 = xr.open_dataset(path_seaice6)

sea_ice6["siconc"][1900].plot()

# %%
path_seaice7 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CanESM5-CanOE_historical_r1i1p2f1_gn_185001-201412.nc"
sea_ice7 = xr.open_dataset(path_seaice7)

sea_ice7["siconc"][1900].plot()

# %%
path_seaice8 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice8 = xr.open_dataset(path_seaice8)

sea_ice8["siconc"][1900].plot()

# %%
path_seaice9 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CESM2-FV2_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice9 = xr.open_dataset(path_seaice9)

sea_ice9["siconc"][1900].plot()
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/conventions.py:193: SerializationWarning: variable 'siconc' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)

# %%
path_seaice10 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CESM2_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice10 = xr.open_dataset(path_seaice10)

sea_ice10["siconc"][1900].plot()
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/conventions.py:193: SerializationWarning: variable 'siconc' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)

# %%
path_seaice11 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CESM2-WACCM-FV2_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice11 = xr.open_dataset(path_seaice11)

sea_ice11["siconc"][1900].plot()
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/conventions.py:193: SerializationWarning: variable 'siconc' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)

# %%
path_seaice12 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CESM2-WACCM_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice12 = xr.open_dataset(path_seaice12)

sea_ice12["siconc"][1900].plot()
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/conventions.py:193: SerializationWarning: variable 'siconc' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)

# %%
path_seaice13 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CNRM-CM6-1_historical_r1i1p1f2_gn_185001-201412.nc"
sea_ice13 = xr.open_dataset(path_seaice13)

sea_ice13["siconc"][1900].plot()

# %%
path_seaice14 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_CNRM-CM6-1-HR_historical_r1i1p1f2_gn_185001-201412.nc"
sea_ice14 = xr.open_dataset(path_seaice14)

sea_ice14["siconc"][1900].plot()

# %%
path_seaice15 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_GFDL-CM4_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice15 = xr.open_dataset(path_seaice15)

sea_ice15["siconc"][1900].plot()

# %%
path_seaice16 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_GFDL-ESM4_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice16 = xr.open_dataset(path_seaice16)

sea_ice16["siconc"][1900].plot()

# %%
path_seaice17 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_INM-CM4-8_historical_r1i1p1f1_gr1_185001-201412.nc"
sea_ice17 = xr.open_dataset(path_seaice17)

sea_ice17["siconc"][1900].plot()

# %%
path_seaice18 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_INM-CM5-0_historical_r1i1p1f1_gr1_185001-201412.nc"
sea_ice18 = xr.open_dataset(path_seaice18)

sea_ice18["siconc"][1900].plot()

# %%
path_seaice19 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_IPSL-CM6A-LR_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice19 = xr.open_dataset(path_seaice19)

sea_ice19["siconc"][1900].plot()

# %%
path_seaice20 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_MIROC6_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice20 = xr.open_dataset(path_seaice20)

sea_ice20["siconc"][1900].plot()

# %%
path_seaice21 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_MIROC-ES2L_historical_r1i1p1f2_gn_185001-201412.nc"
sea_ice21 = xr.open_dataset(path_seaice21)

sea_ice21["siconc"][1900].plot()

# %%
path_seaice22 = "/home/jovyan/private-storage/historical-SImon-siconc/siconc_SImon_MPI-ESM1-2-HR_historical_r1i1p1f1_gn_185001-201412.nc"
sea_ice22 = xr.open_dataset(path_seaice22)

sea_ice22["siconc"][1900].plot()

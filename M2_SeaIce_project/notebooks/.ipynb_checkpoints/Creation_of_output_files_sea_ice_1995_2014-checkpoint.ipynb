# %% [markdown]
# # Creation of output files (tas + siconc files)

# %% [markdown]
# ## Objective
#
# The goal of this notebook is to create output files expressing sea ice as a function of warming level and no longer as a function of time, for all available models.

# %%
from watermark import watermark
# %load_ext watermark
print(watermark())
# Out:
# Last updated: 2025-07-31T12:44:04.453956+00:00
#
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.17.2
#
# Compiler    : GCC 13.3.0
# OS          : Linux
# Release     : 6.8.0-55-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit

# %%
import sys
import os

# Chemin absolu vers le dossier codes_ORL_evaluation
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Ajout du chemin au sys.path
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Projet root ajouté au path:", project_root)
# Out:
# Projet root ajouté au path: /home/jovyan/M2_Snow_project/M2_SeaIce_project

# %%
pip install cdo
# Out:
# Requirement already satisfied: cdo in /srv/conda/envs/notebook/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.12/site-packages (from cdo) (1.17.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from cdo) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from module import *
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
# %watermark --iversions
# Out:
# xarray    : 2025.1.1
# cdo       : 1.6.1
# csv       : 1.0
# xesmf     : 0.8.8
# skimage   : 0.25.0
# seaborn   : 0.13.2
# pandas    : 2.2.3
# watermark : 2.5.0
# netCDF4   : 1.7.2
# sys       : 3.12.8 | packaged by conda-forge | (main, Dec  5 2024, 14:24:40) [GCC 13.3.0]
# numpy     : 2.0.2
# matplotlib: 3.10.0
# cartopy   : 0.24.0

# %%
scenario = 'ssp585'
racineCMIP6="/home/jovyan/private-storage"
racineMasques = "/home/jovyan/private-storage/masques/masques"

Yref1 = 1995
Yref2 = 2014

nmon = 12

Tbinmin = -1.5
Tbinmax = 4.
dtbin = .25
nbin = int((Tbinmax - Tbinmin)/dtbin + 1)
Tbincen = np.linspace(Tbinmin,Tbinmax,nbin)

taboo = []

epsilon = 0.001

def get_models(filelist):
    models = []
    for ific,fichier in enumerate(filelist):
        model = fichier.rsplit("/",1)[1].split("_")[2]
        if (model not in models): 
            models.append(model)
    models.sort()
    return(models)
    
filelist = glob.glob("/home/jovyan/private-storage/historical-Amon-tas/*.nc")
models_Thist = get_models(filelist)

filelist = glob.glob("/home/jovyan/private-storage/historical-SImon-siconc-bis/*.nc")
models_Shist = get_models(filelist)

filelist = glob.glob("/home/jovyan/private-storage/ssp585-Amon-tas-bis/*.nc")
models_Tscen = get_models(filelist)

filelist = glob.glob("/home/jovyan/private-storage/ssp585-SImon-siconc-bis/*.nc")
models_Sscen = get_models(filelist)

models = []
for imod, model in enumerate(models_Thist):
    if (model not in models) and (model not in taboo) and (model in models_Shist) and (model in models_Tscen) and (model in models_Sscen):
        models.append(model)

print(models)

for imod, model in enumerate(models):

  # if ( model == "E3SM-1-1"):

    print("Model : {} {}".format(imod,model))

    # areacella
    #
    champ = 'areacella'
    fichier = glob.glob(racineMasques+'/'+champ+'/'+champ+'_'+model+'.nc')
    if (fichier == []):
        fichier = glob.glob(racineMasques+'/pseudo_'+champ+'/'+champ+'_'+model+'.nc')
    if (fichier == []):
        print("Il manque {} pour {} !".format(champ,model))
        quit()
    print(fichier) #GKtest
    f = netCDF4.Dataset(fichier[0])
    lon = f.variables['lon'][:]
    nlon = lon.size
    lat = f.variables['lat'][:]
    nlat = lat.size
    areacella = f.variables[champ][:,:]
    aireterre = np.sum(areacella)
    # print("Aire Terre : {}".format(aireterre))
    f.close()

    # lire Thist + Tscen, extraire les temps, calculer les temperatures moyennes globales
    #
    champ = 'tas'
    fichier = glob.glob("/home/jovyan/private-storage/historical-Amon-tas/"+"/*_"+model+"_*.nc")
    print(fichier) #GKtest
    fh = netCDF4.Dataset(fichier[0])
    fichier = glob.glob("/home/jovyan/private-storage/ssp585-Amon-tas-bis/"+"/*_"+model+"_*.nc")
    print(fichier) #GKtest
    fs = netCDF4.Dataset(fichier[0])
    nlon2 = fh.variables['lon'][:].size
    nlat2 = fh.variables['lat'][:].size
    if (nlon2 != nlon) or (nlat2 != nlat):
        print("{} : Nombre de longitudes ou latitude faux ! {} {} {} {}".format(model,nlon,nlon2,nlat,nlat2))
        quit()
    tname = fh.variables[champ].dimensions[0]
    timeh = fh.variables[tname][:]
    nth = timeh.shape[0]
    times = fs.variables[tname][:]
    nts = times.shape[0]
    #
    nt = nth + nts
    year = np.empty((nt),int)
    month = np.empty((nt),int)
    GSAT = np.empty((nt),float)
    #
    t_unit = fh.variables[tname].units
    t_cal = fh.variables[tname].calendar
    tvalue = netCDF4.num2date(timeh,units = t_unit,calendar = t_cal)
    for it in range(nth):
        year[it] = tvalue[it].year
        month[it] = tvalue[it].month
        tas = fh.variables[champ][it,:,:]
        tas *= areacella
        GSAT[it] = np.sum(tas[:,:])/aireterre
    #
    t_unit = fs.variables[tname].units
    t_cal = fs.variables[tname].calendar
    tvalue = netCDF4.num2date(times,units = t_unit,calendar = t_cal)
    for it in range(nts):
        year[nth+it] = tvalue[it].year
        month[nth+it] = tvalue[it].month
        tas = fs.variables[champ][it,:,:]
        tas *= areacella
        GSAT[nth+it] = np.sum(tas[:,:])/aireterre
    #
    fh.close()
    fs.close()
    #
    iyref1 = np.argmax(year >= Yref1)
    iyref2 = nt - np.argmax(year[::-1] <= Yref2)
    GSATref = np.average(GSAT[iyref1:iyref2])
    print("  GSAT reference : {}".format(GSATref))
    GSAT[:] -= GSATref
    #
    # GSATsmooth = savgol_filter(GSAT, 12, 3) # window size arg2, polynomial order arg3
    # GSAT smoothed: exponential smoothing, tau=60 = 5 yrs
    tau = 60
    GSATsmooth = np.empty((nt),float)
    GSATsmooth[0] = np.average(GSAT[0:tau])
    for it in range(1,nt):
        GSATsmooth[it] = 1./tau * GSAT[it] + (1. - 1./tau) * GSATsmooth[it-1]

    # lire Shist + Sscen
    #
    fichier = glob.glob("/home/jovyan/private-storage/historical-SImon-siconc-bis/"+"/*_"+model+"_*.nc")
    print(fichier) #GKtest
    fh = netCDF4.Dataset(fichier[0])
    fichier = glob.glob("/home/jovyan/private-storage/ssp585-SImon-siconc-bis/"+"/*_"+model+"_*.nc")
    print(fichier) #GKtest
    fs = netCDF4.Dataset(fichier[0])
    # la grille peut etre differente de celle de T
    nlon = fh.variables['siconc'].shape[2]
    nlat = fh.variables['siconc'].shape[1]
    #
    n_inbin = np.zeros((nbin,nmon),int)
    sicbin = np.zeros((nbin,nmon,nlat,nlon),float) 
    #
    sicread = np.empty((nlat,nlon),float)
    spval = fh.variables["siconc"].missing_value
    for it in range(nt):
        if (it < nth):
            sicread = fh.variables["siconc"][it,:,:]
        else:
            sicread = fs.variables["siconc"][it-nth,:,:]
        ibin = np.argmin(np.abs(GSATsmooth[it]-Tbincen[:]))
        imon = month[it] - 1
        sicbin[ibin,imon,:,:] += sicread[:,:]
        n_inbin[ibin,imon] += 1
    #
    units = fh.variables["siconc"].units
    stdname = fh.variables["siconc"].standard_name
    longname = fh.variables["siconc"].long_name

    # normaliser les bins
    #
    for ibin in range(nbin):
        for imon in range(nmon):
            if (n_inbin[ibin,imon] > 0):
                sicbin[ibin,imon,:,:] /= n_inbin[ibin,imon]
            else:
                sicbin[ibin,imon,:,:] = spval

    # pour graphique warming level
    levels = [ 10., 25., 50., 75., 90.]
    nlev = len(levels)

    swl = np.empty((nlev,nmon,nlat,nlon),float)
    for ilev,level in enumerate(levels):
        xgtl = np.where( (sicbin > level) & (np.abs(sicbin/spval -1.) > epsilon), dtbin, 0)
        swl[ilev,:,:,:] = np.sum(xgtl, axis = 0)
        swl[ilev,:,:,:] = np.where( (np.abs(sicbin[int(nbin/2),:,:,:]/spval -1.) > epsilon), swl[ilev,:,:,:], spval) + Tbinmin

    # ecrire
    #
    f = netCDF4.Dataset('/home/jovyan/private-storage/SiconcWarming_1995_2014/SiconcWarming_'+model+'_historical+'+scenario+'.nc',mode='w',format='NETCDF4_CLASSIC')
    #
    monname = 'month'
    month_dim = f.createDimension(monname, nmon)
    months = f.createVariable(monname, float, (monname,))
    months.units = 'months'
    months.long_name = 'month'
    months.standard_name = 'month'
    months.axis = 'T'
    #
    binname = 'GSAT'
    tbin_dim = f.createDimension(binname, nbin)
    tbins = f.createVariable(binname, float, (binname,))
    tbins.units = 'K'
    tbins.long_name = 'GSAT wrt. 1995-2014'
    tbins.standard_name = 'GSAT'
    tbins.axis = 'Z'
    #
    levelname = 'Level'
    lev_dim = f.createDimension(levelname, nlev)
    levs = f.createVariable(levelname, float, (levelname,))
    levs.units = '%'
    levs.long_name = 'Level'
    levs.standard_name = 'Level'
    levs.axis = 'Z'
    #
    # copier les dimensions spatiales de siconc (fichier original)
    dimlist = []
    for idim in range(1,3):
        dimlist.append(fh.variables['siconc'].dimensions[idim])
    try:
        dimlist.append(fh.variables['type'].dimensions[0])
    except:
        pass
    for dname, the_dim in fh.dimensions.items():
        if (dname in dimlist):
            f.createDimension(dname, len(the_dim))
    # copier les variables qui sont des coordonnees de siconc (car elles sont aussi des coordonnees de variables de sortie)
    #
    coordinates = fh.variables['siconc'].getncattr('coordinates')
    coordlist = coordinates.split()
    # Traitement special pour INM-CM4-8, INM-CM5-0 et E3SM-1-1:
    if ( model == 'INM-CM4-8') or (model == 'INM-CM5-0') or (model == 'E3SM-1-1'):
        coordlist = ['type', 'lat', 'lon']
    for v_name, varin in fh.variables.items():
        for coordinate in coordlist:
            if (v_name == coordinate) and (v_name != 'time'):
                #
                dimensions = varin.dimensions
                outVar = f.createVariable(v_name, varin.datatype, dimensions)
                #
                attributes = {k: varin.getncattr(k) for k in varin.ncattrs()}
                try:
                    del attributes["_FillValue"]
                except:
                    pass
                outVar.setncatts(attributes)
                #
                outVar[:] = varin[:]
    #
    sicbins = f.createVariable('siconcbin',float,(binname,monname,dimlist[0],dimlist[1]))
    sicbins.missing_value = spval
    sicbins.units = units
    sicbins.standard_name = stdname
    sicbins.long_name = longname
    sicbins.coordinates = coordinates
    #
    swls = f.createVariable('Limit',float,(levelname,monname,dimlist[0],dimlist[1]))
    swls.missing_value = spval
    swls.units = 'K'
    swls.standard_name = 'Limit'
    swls.long_name = 'Limit'
    swls.coordinates = coordinates
    #
    months[:] = month[:nmon]
    tbins[:] = Tbincen[:]
    levs[:] = levels[:]
    sicbins[:,:,:,:] = sicbin[:,:,:,:]
    swls[:,:,:,:] = swl[:,:,:,:]
    #
    f.close()
    #
    fh.close()
    fs.close()
# Out:
# ['ACCESS-CM2', 'ACCESS-ESM1-5', 'BCC-CSM2-MR', 'CAMS-CSM1-0', 'CAS-ESM2-0', 'CESM2', 'CESM2-WACCM', 'CMCC-CM2-SR5', 'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'CanESM5', 'CanESM5-CanOE', 'E3SM-1-1', 'EC-Earth3', 'EC-Earth3-Veg', 'EC-Earth3-Veg-LR', 'FGOALS-f3-L', 'FGOALS-g3', 'FIO-ESM-2-0', 'GFDL-CM4', 'GFDL-ESM4', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'INM-CM4-8', 'INM-CM5-0', 'IPSL-CM6A-LR', 'MIROC-ES2L', 'MIROC6', 'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NESM3', 'NorESM2-LM', 'NorESM2-MM', 'UKESM1-0-LL']
# Model : 0 ACCESS-CM2
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_ACCESS-CM2.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 287.52366129557294
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_ACCESS-CM2_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_ACCESS-CM2_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 1 ACCESS-ESM1-5
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_ACCESS-ESM1-5.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 288.475580851237
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_ACCESS-ESM1-5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_ACCESS-ESM1-5_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 2 BCC-CSM2-MR
# ['/home/jovyan/private-storage/masques/masques/pseudo_areacella/areacella_BCC-CSM2-MR.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 288.5494617660102
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_BCC-CSM2-MR_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 3 CAMS-CSM1-0
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CAMS-CSM1-0.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CAMS-CSM1-0_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CAMS-CSM1-0_ssp585_r1i1p1f1_gn_201501-209912.nc']
#   GSAT reference : 287.6659473419189
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CAMS-CSM1-0_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CAMS-CSM1-0_ssp585_r1i1p1f1_gn_201501-209912.nc']
# Model : 4 CAS-ESM2-0
# ['/home/jovyan/private-storage/masques/masques/pseudo_areacella/areacella_CAS-ESM2-0.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CAS-ESM2-0_historical_r2i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CAS-ESM2-0_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 287.6964511224841
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CAS-ESM2-0_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CAS-ESM2-0_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 5 CESM2
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CESM2.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CESM2_historical_r1i1p1f1_gn_185001-201412.nc']
# /tmp/ipykernel_4522/4248700496.py:69: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   areacella = f.variables[champ][:,:]
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CESM2_ssp585_r1i1p1f1_gn_201501-210012.nc']
# /tmp/ipykernel_4522/4248700496.py:105: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   tas = fh.variables[champ][it,:,:]
# /tmp/ipykernel_4522/4248700496.py:115: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   tas = fs.variables[champ][it,:,:]
#   GSAT reference : 288.01427192687987
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CESM2_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CESM2_ssp585_r1i1p1f1_gn_201501-210012.nc']
# /tmp/ipykernel_4522/4248700496.py:155: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   sicread = fh.variables["siconc"][it,:,:]
# /tmp/ipykernel_4522/4248700496.py:157: UserWarning: WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#   sicread = fs.variables["siconc"][it-nth,:,:]
# Model : 6 CESM2-WACCM
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CESM2-WACCM.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CESM2-WACCM_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CESM2-WACCM_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 287.87901598612467
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CESM2-WACCM_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CESM2-WACCM_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 7 CMCC-CM2-SR5
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CMCC-CM2-SR5.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 288.3089959462484
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CMCC-CM2-SR5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CMCC-CM2-SR5_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 8 CNRM-CM6-1
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CNRM-CM6-1.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CNRM-CM6-1_historical_r1i1p1f2_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CNRM-CM6-1_ssp585_r1i1p1f2_gr_201501-210012.nc']
#   GSAT reference : 286.8446324666341
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CNRM-CM6-1_historical_r1i1p1f2_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CNRM-CM6-1_ssp585_r1i1p1f2_gn_201501-210012.nc']
# Model : 9 CNRM-CM6-1-HR
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CNRM-CM6-1-HR.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CNRM-CM6-1-HR_historical_r1i1p1f2_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr_201501-210012.nc']
#   GSAT reference : 286.5629592895508
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CNRM-CM6-1-HR_historical_r1i1p1f2_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gn_201501-210012.nc']
# Model : 10 CNRM-ESM2-1
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CNRM-ESM2-1.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CNRM-ESM2-1_historical_r1i1p1f2_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_201501-210012.nc']
#   GSAT reference : 287.4973690032959
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CNRM-ESM2-1_historical_r1i1p1f2_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CNRM-ESM2-1_ssp585_r1i1p1f2_gn_201501-210012.nc']
# Model : 11 CanESM5
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CanESM5.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CanESM5_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 287.9440989176432
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CanESM5_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 12 CanESM5-CanOE
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_CanESM5-CanOE.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_CanESM5-CanOE_historical_r1i1p2f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_CanESM5-CanOE_ssp585_r1i1p2f1_gn_201501-210012.nc']
#   GSAT reference : 287.8327458699544
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_CanESM5-CanOE_historical_r1i1p2f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_CanESM5-CanOE_ssp585_r1i1p2f1_gn_201501-210012.nc']
# Model : 13 E3SM-1-1
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_E3SM-1-1.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_E3SM-1-1_historical_r1i1p1f1_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_E3SM-1-1_ssp585_r1i1p1f1_gr_201501-210012.nc']
#   GSAT reference : 287.3523080190023
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_E3SM-1-1_historical_r1i1p1f1_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_E3SM-1-1_ssp585_r1i1p1f1_gr_201501-210012.nc']
# Model : 14 EC-Earth3
# ['/home/jovyan/private-storage/masques/masques/pseudo_areacella/areacella_EC-Earth3.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_EC-Earth3_historical_r1i1p1f1_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_EC-Earth3_ssp585_r1i1p1f1_gr_201501-210012.nc']
#   GSAT reference : 287.96432398507545
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_EC-Earth3_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_EC-Earth3_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 15 EC-Earth3-Veg
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_EC-Earth3-Veg.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_EC-Earth3-Veg_historical_r1i1p1f1_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_EC-Earth3-Veg_ssp585_r1i1p1f1_gr_201501-210012.nc']
#   GSAT reference : 288.0503209431966
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_EC-Earth3-Veg_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_EC-Earth3-Veg_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 16 EC-Earth3-Veg-LR
# ['/home/jovyan/private-storage/masques/masques/areacella/areacella_EC-Earth3-Veg-LR.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_EC-Earth3-Veg-LR_historical_r1i1p1f1_gr_185101-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_EC-Earth3-Veg-LR_ssp585_r1i1p1f1_gr_201501-210012.nc']
#   GSAT reference : 287.70674096970333
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_EC-Earth3-Veg-LR_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_EC-Earth3-Veg-LR_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 17 FGOALS-f3-L
# ['/home/jovyan/private-storage/masques/masques/pseudo_areacella/areacella_FGOALS-f3-L.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_FGOALS-f3-L_historical_r1i1p1f1_gr_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_FGOALS-f3-L_ssp585_r1i1p1f1_gr_201501-210012.nc']
#   GSAT reference : 286.96104932618834
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_FGOALS-f3-L_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_FGOALS-f3-L_ssp585_r1i1p1f1_gn_201501-210012.nc']
# Model : 18 FGOALS-g3
# ['/home/jovyan/private-storage/masques/masques/pseudo_areacella/areacella_FGOALS-g3.nc']
# ['/home/jovyan/private-storage/historical-Amon-tas/tas_Amon_FGOALS-g3_historical_r1i1p1f1_gn_185001-201612.nc']
# ['/home/jovyan/private-storage/ssp585-Amon-tas-bis/tas_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_201501-210012.nc']
#   GSAT reference : 286.9664652128735
# ['/home/jovyan/private-storage/historical-SImon-siconc-bis/siconc_SImon_FGOALS-g3_historical_r1i1p1f1_gn_185001-201412.nc']
# ['/home/jovyan/private-storage/ssp585-SImon-siconc-bis/siconc_SImon_FGOALS-g3_ssp585_r1i1p1f1_gn_201501-210012.nc']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 155
#     153 for it in range(nt):
#     154     if (it < nth):
# --> 155         sicread = fh.variables["siconc"][it,:,:]
#     156     else:
#     157         sicread = fs.variables["siconc"][it-nth,:,:]
#
# File src/netCDF4/_netCDF4.pyx:5079, in netCDF4._netCDF4.Variable.__getitem__()
#
# File src/netCDF4/_netCDF4.pyx:6049, in netCDF4._netCDF4.Variable._get()
#
# IndexError: index exceeds dimension bounds
